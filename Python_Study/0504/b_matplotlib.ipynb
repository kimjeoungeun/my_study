# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
# #jupyter notebook에서 그려주세요. 
# %matplotlib qt #별도의 팝업창에서 그래프 출력(colab X)

# %% [markdown]
# - 선그래프

# %%
data = [10,40,20,60,70]

plt.plot(data)

# %% [markdown]
# - xlim, ylim
# x축의 길이와, y축의 길이 조정

# %%
x = np.arange(10)
y =x+10
plt.plot(x,y)

# %%
plt.xlim([0,10])
plt.ylim([0,20])

plt.plot(x,y) # 축 지정 잘할것

# %%
x=np.arange(-np.pi, np.pi,0.02)
y1=np.sin(x)
y2=np.cos(x)

plt.plot(x,y1,label="sin", color=(0.1,0.3,0.5)) # RGB color
plt.plot(x,y2,label="cos", color="#FF6699")
plt.legend()

# %%
plt.plot([1,2,3,4],[2,3,5,10], 'bo--') # blue + o 마크 + --- 이것으로 이어주세요
plt.xlabel('T-Axis')
# Out:
# Text(0.5, 0, 'T-Axis')

# %%
x=np.arange(10)
y1=x
y2=x**2-x

fig,axs=plt.subplots(2,1)
fig.set_facecolor("#FF6699") # 뒷배경

axs[0].plot(x,y1) # 첫번째 행
axs[1].plot(x,y2) # 두번째 행

axs[0].set_facecolor('pink') # 첫번째 행의 배경
axs[1].set_facecolor('skyblue') # 두번째 행의 배경

# %%
x=np.arange(-5,5,0.5)
y1=x
y2=x**2
y3=np.sin(x)
y4=np.cos(x)

plt.plot(x,y1)
plt.plot(x,y2, marker='d')
plt.plot(x,y3, color='r')
plt.plot(x,y4, linestyle='dashed')

# %% [markdown]
# - bar plot

# %%
data = {'사과':21, '바나나':15, '배':5,'키위':20}
names = list(data.keys())
values = list(data.values())

fig,ax = plt.subplots()
ax.bar(names,values)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# - hist

# %%
data=np.random.rand(10000)
fix,ax=plt.subplots()
ax.hist(data,bins=100, facecolor="r")
plt.show()

# %% [markdown]
# - 2d Scatter plot

# %%
n=50
x=np.random.rand(n)
y=np.random.rand(n)

plt.scatter(x,y)
plt.show()
